# %% [markdown]
# ### For intercative visualizations you have to run this page. Otherwise it will how only blank space

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__)
# Out:
# 5.18.0

# %%
import cufflinks as cf
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])
df
# Out:
#            A         B         C         D
# 0  -0.769808  1.131876 -0.639430  0.090105
# 1   0.006497 -0.966355  1.252455 -1.995728
# 2   2.497629 -1.326329  1.542860 -0.231480
# 3  -1.046443  0.228586 -1.078012 -0.584255
# 4  -2.199400 -0.576711  0.022692 -0.147813
# ..       ...       ...       ...       ...
# 95  1.492033 -0.411204  0.598372 -0.765941
# 96 -0.299695  1.682976 -0.572387 -1.807249
# 97  0.844372 -1.445186 -0.220135  1.640650
# 98 -0.689079 -1.055370  0.050682 -1.679023
# 99 -0.559477  0.344701  0.113940  0.524115
#
# [100 rows x 4 columns]

# %%
df2=pd.DataFrame({'category':['A','B','C'],'values':[32,43,50]})
df2
# Out:
#   category  values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Using Cufflinks and iplot()
#
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10,color='red')
# Out:
# <div>                            <div id="a10bf11f-731e-4521-8623-b92683e0054f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Bar Plots

# %%
df2.iplot(kind='bar',x='category',y='values')
# Out:
# <div>                            <div id="95fcc47b-ba20-4306-84ad-9b3ce1432388" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>                            <div id="5ef717d9-4b4c-42bb-bad7-808a9b74b9b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="a4d21bf3-6eca-4f5d-b3b3-b3f46c1a5a38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum()
# Out:
# A    4.382489
# B   -0.721116
# C    7.565262
# D   -9.300638
# dtype: float64

# %% [markdown]
# ## Boxplots

# %%
df2.iplot(kind='box')
# Out:
# <div>                            <div id="000c609b-5a4e-4cb3-8c8e-551491369601" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="e5295133-736d-4072-8a4c-218040eb6676" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## 3d Surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="8814022d-4126-41f6-aff6-6daa16e62798" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## histogram

# %%
df['A']
# Out:
# 0    -0.769808
# 1     0.006497
# 2     2.497629
# 3    -1.046443
# 4    -2.199400
#         ...
# 95    1.492033
# 96   -0.299695
# 97    0.844372
# 98   -0.689079
# 99   -0.559477
# Name: A, Length: 100, dtype: float64

# %%
df[['A','B','C']].iplot(kind='hist' ,bins=25)
# Out:
# <div>                            <div id="5a087099-f52e-4573-89ce-8e324f02cf43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='D')
# Out:
# <div>                            <div id="a2e7dba7-50c5-4333-bcc2-507415ffbf25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## scatter_matrix()
#
# Similar to sns.pairplot()

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="e639f93b-c517-4404-b875-95866fbcf4ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
a=df.corr()
a
# Out:
#           A         B         C         D
# A  1.000000 -0.032756  0.254927 -0.011029
# B -0.032756  1.000000 -0.163526 -0.037211
# C  0.254927 -0.163526  1.000000 -0.085494
# D -0.011029 -0.037211 -0.085494  1.000000

# %%
df.corr().iplot(kind='heatmap')
# Out:
# <div>                            <div id="cdc7e273-ba46-4271-bcd9-ceb633d0ead9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
